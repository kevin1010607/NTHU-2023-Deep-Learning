# %% [markdown]
# # Lab15_108032053

# %% [markdown]
# ## 1. Model & Training

# %%
import numpy as np
import matplotlib.pyplot as plt
import moviepy.editor as mpy
import skimage.transform
from IPython.display import Image, display

import tensorflow as tf
import tensorflow_probability as tfp
import tensorflow.keras.losses as kls
# Out:
# 2024-01-03 00:00:51.355861: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-03 00:00:51.355915: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-03 00:00:51.355942: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-03 00:00:51.365316: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices("GPU") 
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2024-01-03 00:00:53.657005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31136 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:b1:00.0, compute capability: 7.0

# %%
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"  # this line make pop-out window not appear
from ple.games.flappybird import FlappyBird
from ple import PLE

game = FlappyBird()
env = PLE(game, fps=30, display_screen=False)  # environment interface to game
env.reset_game()

test_game = FlappyBird()
test_env = PLE(test_game, fps=30, display_screen=False)
test_env.reset_game()
# Out:
# couldn't import doomish
# Couldn't import doom
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile

# %%
path = './movie_f' 
if not os.path.exists(path):
    os.makedirs(path)

# %%
hparas = {
    'image_size': 84,
    'num_stack': 4,
    'action_dim': len(env.getActionSet()),
    'hidden_size': 256,
    'lr': 0.0001,
    'gamma': 0.99,
    'lambda': 0.95,
    'clip_val': 0.2,
    'ppo_epochs': 8,
    'test_epochs': 1,
    'num_steps': 512,
    'mini_batch_size': 64,
    'target_reward': 200,
    'max_episode': 30000,
}

# %%
def make_anim(images, fps=60, true_image=False):
    duration = len(images) / fps

    def make_frame(t):
        try:
            x = images[int(len(images) / duration * t)]
        except:
            x = images[-1]

        if true_image:
            return x.astype(np.uint8)
        else:
            return ((x + 1) / 2 * 255).astype(np.uint8)

    clip = mpy.VideoClip(make_frame, duration=duration)
    clip.fps = fps
    
    return clip

# %%
def preprocess_screen(screen):
    screen = skimage.transform.rotate(screen, -90, resize=True)
    screen = screen[:400, :]
    screen = skimage.transform.resize(screen, [hparas['image_size'], hparas['image_size'], 1])
    return screen.astype(np.float32)

def frames_to_state(input_frames):
    if(len(input_frames) == 1):
        state = np.concatenate(input_frames*4, axis=-1)
    elif(len(input_frames) == 2):
        state = np.concatenate(input_frames[0:1]*2 + input_frames[1:]*2, axis=-1)
    elif(len(input_frames) == 3):
        state = np.concatenate(input_frames + input_frames[2:], axis=-1)
    else:
        state = np.concatenate(input_frames[-4:], axis=-1)

    return state

# %%
class ActorCriticNetwork(tf.keras.Model):
    def __init__(self, hparas):
        super().__init__()

        self.feature_extractor = tf.keras.Sequential([
          # Convolutional Layers
          tf.keras.layers.Conv2D(filters=32, kernel_size=8, strides=4),
          tf.keras.layers.ReLU(),
          tf.keras.layers.Conv2D(filters=64, kernel_size=4, strides=2),
          tf.keras.layers.ReLU(),
          tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1),
          tf.keras.layers.ReLU(),
          # Embedding Layers
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(hparas['hidden_size']),
          tf.keras.layers.ReLU(),
        ])

        # Actor Network
        self.actor = tf.keras.layers.Dense(hparas['action_dim'], activation='softmax')
        # Critic Network
        self.critic = tf.keras.layers.Dense(1, activation = None)

    def call(self, input):
        x = self.feature_extractor(input)
        action_logits = self.actor(x)
        value = self.critic(x)
        return action_logits, value

# %%
class Agent():
    def __init__(self, hparas):
        self.gamma = hparas['gamma']
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=hparas['lr'])
        self.actor_critic = ActorCriticNetwork(hparas)
        self.clip_pram = hparas['clip_val']
    
    def ppo_iter(self, mini_batch_size, states, actions, log_probs, returns, advantage):
        batch_size = states.shape[0]
        for _ in range(batch_size // mini_batch_size):
            rand_ids = tf.convert_to_tensor(np.random.randint(0, batch_size, mini_batch_size), dtype=tf.int32)
            yield tf.gather(states, rand_ids), tf.gather(actions, rand_ids), tf.gather(log_probs, rand_ids), \
             tf.gather(returns, rand_ids), tf.gather(advantage, rand_ids)
    
    def ppo_update(self, ppo_epochs, mini_batch_size, states, actions, log_probs, discount_rewards, advantages):       
        total_actor_loss = 0
        total_critic_loss = 0
        for _ in range(ppo_epochs):
            for state, action, old_log_probs, reward, advantage in self.ppo_iter(mini_batch_size, states, actions, log_probs, discount_rewards, advantages):
                reward = tf.expand_dims(reward, axis=-1)

                with tf.GradientTape() as tape:
                    prob, value = self.actor_critic(state, training=True)
                    dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
                    entropy = tf.math.reduce_mean(dist.entropy())
                    new_log_probs = dist.log_prob(action)

                    # PPO ratio
                    ratio = tf.math.exp(new_log_probs - old_log_probs)
                    surr1 = ratio * advantage
                    surr2 = tf.clip_by_value(ratio, 1.0 - self.clip_pram, 1.0 + self.clip_pram) * advantage

                    actor_loss = tf.math.negative(tf.math.reduce_mean(tf.math.minimum(surr1, surr2))) - 0.1 * entropy
                    critic_loss = 0.5 * tf.math.reduce_mean(kls.mean_squared_error(reward, value))

                    total_loss = actor_loss + critic_loss
            
                # single optimizer
                grads = tape.gradient(total_loss, self.actor_critic.trainable_variables)
                self.optimizer.apply_gradients(zip(grads, self.actor_critic.trainable_variables))
      
                total_actor_loss += actor_loss
                total_critic_loss += critic_loss
        return total_actor_loss, total_critic_loss

# %%
# https://arxiv.org/pdf/1506.02438.pdf
# Equation 16
def compute_gae(rewards, masks, values, gamma, LAMBDA):
    gae = 0
    returns = []
    for i in reversed(range(len(rewards))):
        delta = rewards[i] + gamma * values[i + 1] * masks[i] - values[i]
        gae = delta + gamma * LAMBDA * masks[i] * gae
        returns.append(gae + values[i])

    returns.reverse()
    return returns

# %%
def test_reward(test_env, agent):
    total_reward = 0
    # Reset the environment
    test_env.reset_game()
    input_frames = [preprocess_screen(test_env.getScreenGrayscale())]

    while not test_env.game_over():

        state = frames_to_state(input_frames)
        state = tf.expand_dims(state, axis=0)
        prob, value = agent.actor_critic(state)

        action = np.argmax(prob[0].numpy())
        reward = test_env.act(test_env.getActionSet()[action])
        total_reward += reward

        input_frames.append(preprocess_screen(test_env.getScreenGrayscale()))

    return total_reward

# %%
agent = Agent(hparas)
max_episode = hparas['max_episode']
test_per_n_episode = 10
force_save_per_n_episode = 1000
early_stop_reward = 10

start_s = 0
best_reward = -5.0

checkpoint = tf.train.Checkpoint(
    actor_critic = agent.actor_critic,
    optimizer = agent.optimizer,
)

# Load from old checkpoint
# checkpoint.restore('ckpt_dir/ckpt-?')

# %%
ep_reward = []
total_avgr = []
early_stop = False
avg_rewards_list = []

env.reset_game()

for s in range(0, max_episode):
    if early_stop == True:
        break

    rewards = []
    states = []
    actions = []
    log_probs = []
    masks = []
    values = []

    display_frames = [env.getScreenRGB()]
    input_frames = [preprocess_screen(env.getScreenGrayscale())]

    for step in range(hparas['num_steps']):

        state = frames_to_state(input_frames)
        state = tf.expand_dims(state, axis=0)
        prob, value = agent.actor_critic(state)

        dist = tfp.distributions.Categorical(probs=prob[0], dtype=tf.float32)
        action = dist.sample(1)
        log_prob = dist.log_prob(action)

        reward = env.act(env.getActionSet()[int(action.numpy())])

        done = env.game_over()

        states.append(state)
        actions.append(action)
        values.append(value[0])
        log_probs.append(log_prob)
        rewards.append(tf.convert_to_tensor(reward, dtype=tf.float32))
        masks.append(tf.convert_to_tensor(1-int(done), dtype=tf.float32))

        display_frames.append(env.getScreenRGB())
        input_frames.append(preprocess_screen(env.getScreenGrayscale()))

        if done:
            env.reset_game()
            input_frames = [preprocess_screen(env.getScreenGrayscale())]
  
    _, next_value = agent.actor_critic(state)
    values.append(next_value[0])

    returns = compute_gae(rewards, masks, values, hparas['gamma'], hparas['lambda'])

    returns = tf.concat(returns, axis=0)
    log_probs = tf.concat(log_probs, axis=0)
    values = tf.concat(values, axis=0)
    states = tf.concat(states, axis=0)
    actions = tf.concat(actions, axis=0)
    advantage = returns - values[:-1]

    a_loss, c_loss = agent.ppo_update(hparas['ppo_epochs'], hparas['mini_batch_size'], states, actions, log_probs, returns, advantage)
    print('[Episode %d]  Actor loss: %.5f, Critic loss: %.5f' % (s, a_loss, c_loss))

    if s % test_per_n_episode == 0:
        # test agent hparas['test_epochs'] times to get the average reward
        avg_reward = np.mean([test_reward(test_env, agent) for _ in range(hparas['test_epochs'])])
        print("Test average reward is %.1f, Current best average reward is %.1f\n" % (avg_reward, best_reward))
        avg_rewards_list.append(avg_reward)

        if avg_reward > best_reward:
            best_reward = avg_reward
            agent.actor_critic.save('./save/Actor/model_actor_{}_{}'.format(s, avg_reward), save_format="tf")
            checkpoint.save(file_prefix = './save/checkpoints/ckpt')

    if s % force_save_per_n_episode == 0:
        agent.actor_critic.save('./save/Actor/model_actor_{}_{}'.format(s, avg_reward), save_format="tf")
        checkpoint.save(file_prefix = './save/checkpoints/ckpt')
        clip = make_anim(display_frames, fps=60, true_image=True).rotate(-90)
        clip.write_videofile("movie_f/{}_demo-{}.webm".format('Lab15', s), fps=60)
        display(clip.ipython_display(fps=60, autoplay=1, loop=1, maxduration=120))

    if best_reward >= early_stop_reward:
        early_stop = True
# Out:
# 2024-01-03 00:00:55.026636: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8906
# 2024-01-03 00:01:08.926586: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56107e7a1f20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-03 00:01:08.926623: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2024-01-03 00:01:08.936553: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-03 00:01:09.017115: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f5d1ff4c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f5d1ff4c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [Episode 0]  Actor loss: 86.21421, Critic loss: 59.75151
# Test average reward is -5.0, Current best average reward is -5.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_0_-5.0/assets
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_0_-5.0/assets
# Moviepy - Building video movie_f/Lab15_demo-0.webm.
# Moviepy - Writing video movie_f/Lab15_demo-0.webm
# Moviepy - Done !
# Moviepy - video ready movie_f/Lab15_demo-0.webm
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video autoplay='1' loop='1'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# [Episode 1]  Actor loss: 35.88290, Critic loss: 26.41533
# [Episode 2]  Actor loss: 35.92574, Critic loss: 22.29245
# [Episode 3]  Actor loss: 16.55899, Critic loss: 10.39134
# [Episode 4]  Actor loss: 21.13348, Critic loss: 10.99999
# [Episode 5]  Actor loss: 10.39707, Critic loss: 6.96987
# [Episode 6]  Actor loss: 9.64706, Critic loss: 5.22790
# [Episode 7]  Actor loss: 2.86627, Critic loss: 4.48298
# [Episode 8]  Actor loss: -3.23313, Critic loss: 3.98757
# [Episode 9]  Actor loss: 2.97530, Critic loss: 2.91045
# [Episode 10]  Actor loss: -0.29919, Critic loss: 3.42077
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 11]  Actor loss: -3.25367, Critic loss: 3.21691
# [Episode 12]  Actor loss: -0.21270, Critic loss: 2.88098
# [Episode 13]  Actor loss: -2.39696, Critic loss: 2.14817
# [Episode 14]  Actor loss: -7.43690, Critic loss: 1.75484
# [Episode 15]  Actor loss: -5.80470, Critic loss: 2.36451
# [Episode 16]  Actor loss: -4.33840, Critic loss: 2.18721
# [Episode 17]  Actor loss: -3.58236, Critic loss: 2.13229
# [Episode 18]  Actor loss: -3.14842, Critic loss: 2.13819
# [Episode 19]  Actor loss: -5.46064, Critic loss: 2.24969
# [Episode 20]  Actor loss: -11.05514, Critic loss: 2.93658
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 21]  Actor loss: -7.38124, Critic loss: 1.88400
# [Episode 22]  Actor loss: -11.01214, Critic loss: 1.86340
# [Episode 23]  Actor loss: -7.46313, Critic loss: 1.99477
# [Episode 24]  Actor loss: -8.60471, Critic loss: 1.64873
# [Episode 25]  Actor loss: -7.96470, Critic loss: 1.77381
# [Episode 26]  Actor loss: -7.16508, Critic loss: 1.64252
# [Episode 27]  Actor loss: -5.28061, Critic loss: 1.99954
# [Episode 28]  Actor loss: -4.87308, Critic loss: 1.39287
# [Episode 29]  Actor loss: 0.49154, Critic loss: 1.96111
# [Episode 30]  Actor loss: -4.29087, Critic loss: 1.78974
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 31]  Actor loss: -9.33313, Critic loss: 1.65139
# [Episode 32]  Actor loss: -6.91872, Critic loss: 1.36428
# [Episode 33]  Actor loss: -7.92454, Critic loss: 0.88396
# [Episode 34]  Actor loss: -5.40201, Critic loss: 1.42569
# [Episode 35]  Actor loss: -4.19914, Critic loss: 1.04792
# [Episode 36]  Actor loss: -3.21123, Critic loss: 1.38075
# [Episode 37]  Actor loss: -4.49091, Critic loss: 3.68637
# [Episode 38]  Actor loss: -11.40611, Critic loss: 0.90956
# [Episode 39]  Actor loss: -7.23945, Critic loss: 0.82536
# [Episode 40]  Actor loss: -4.63959, Critic loss: 1.31223
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 41]  Actor loss: -6.84924, Critic loss: 1.56900
# [Episode 42]  Actor loss: -4.83209, Critic loss: 1.06413
# [Episode 43]  Actor loss: -4.17495, Critic loss: 0.99813
# [Episode 44]  Actor loss: -4.85335, Critic loss: 0.78779
# [Episode 45]  Actor loss: -0.20938, Critic loss: 1.70035
# [Episode 46]  Actor loss: 3.57363, Critic loss: 1.08070
# [Episode 47]  Actor loss: -0.80509, Critic loss: 0.89452
# [Episode 48]  Actor loss: -4.84524, Critic loss: 0.76918
# [Episode 49]  Actor loss: -10.58106, Critic loss: 1.68406
# [Episode 50]  Actor loss: -0.93929, Critic loss: 0.77621
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 51]  Actor loss: -10.40209, Critic loss: 0.82697
# [Episode 52]  Actor loss: -5.56246, Critic loss: 0.52932
# [Episode 53]  Actor loss: -2.73294, Critic loss: 0.76629
# [Episode 54]  Actor loss: -8.26827, Critic loss: 0.56549
# [Episode 55]  Actor loss: -3.34799, Critic loss: 1.16279
# [Episode 56]  Actor loss: -5.17429, Critic loss: 0.59845
# [Episode 57]  Actor loss: -2.70009, Critic loss: 0.68139
# [Episode 58]  Actor loss: -4.85823, Critic loss: 0.76100
# [Episode 59]  Actor loss: -6.23342, Critic loss: 0.84292
# [Episode 60]  Actor loss: -3.36022, Critic loss: 0.93563
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 61]  Actor loss: -6.82219, Critic loss: 0.49703
# [Episode 62]  Actor loss: -6.95880, Critic loss: 0.64518
# [Episode 63]  Actor loss: -2.47067, Critic loss: 0.51481
# [Episode 64]  Actor loss: -12.68819, Critic loss: 1.40295
# [Episode 65]  Actor loss: 0.38840, Critic loss: 0.77663
# [Episode 66]  Actor loss: -7.53375, Critic loss: 0.53230
# [Episode 67]  Actor loss: -7.87606, Critic loss: 0.54870
# [Episode 68]  Actor loss: -4.98719, Critic loss: 0.74403
# [Episode 69]  Actor loss: -3.71767, Critic loss: 0.71245
# [Episode 70]  Actor loss: -8.77582, Critic loss: 1.53290
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 71]  Actor loss: -12.05153, Critic loss: 1.24768
# [Episode 72]  Actor loss: -3.94271, Critic loss: 1.17199
# [Episode 73]  Actor loss: -3.74253, Critic loss: 0.79333
# [Episode 74]  Actor loss: -7.76301, Critic loss: 0.51180
# [Episode 75]  Actor loss: -4.87420, Critic loss: 1.06401
# [Episode 76]  Actor loss: -6.72616, Critic loss: 0.52951
# [Episode 77]  Actor loss: -5.07834, Critic loss: 0.54215
# [Episode 78]  Actor loss: 0.18396, Critic loss: 0.91591
# [Episode 79]  Actor loss: -6.31434, Critic loss: 0.49947
# [Episode 80]  Actor loss: -8.77126, Critic loss: 0.40887
# Test average reward is -4.0, Current best average reward is -5.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_80_-4.0/assets
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_80_-4.0/assets
# [Episode 81]  Actor loss: -1.90184, Critic loss: 0.75246
# [Episode 82]  Actor loss: -4.45743, Critic loss: 0.79861
# [Episode 83]  Actor loss: -3.91775, Critic loss: 0.35031
# [Episode 84]  Actor loss: -4.08054, Critic loss: 1.29376
# [Episode 85]  Actor loss: -5.07557, Critic loss: 0.60348
# [Episode 86]  Actor loss: -5.30708, Critic loss: 0.85273
# [Episode 87]  Actor loss: -1.61056, Critic loss: 0.72088
# [Episode 88]  Actor loss: -4.68715, Critic loss: 0.45143
# [Episode 89]  Actor loss: -3.65534, Critic loss: 0.53827
# [Episode 90]  Actor loss: -4.60834, Critic loss: 0.45566
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 91]  Actor loss: -5.79653, Critic loss: 0.38631
# [Episode 92]  Actor loss: -4.19550, Critic loss: 0.44622
# [Episode 93]  Actor loss: -5.82714, Critic loss: 0.37591
# [Episode 94]  Actor loss: -3.21290, Critic loss: 0.54959
# [Episode 95]  Actor loss: -5.04592, Critic loss: 0.49039
# [Episode 96]  Actor loss: -5.31943, Critic loss: 0.38310
# [Episode 97]  Actor loss: -2.43163, Critic loss: 0.57926
# [Episode 98]  Actor loss: -12.31057, Critic loss: 0.76729
# [Episode 99]  Actor loss: -3.15349, Critic loss: 0.66864
# [Episode 100]  Actor loss: -6.85360, Critic loss: 0.38562
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 101]  Actor loss: -4.94894, Critic loss: 0.32230
# [Episode 102]  Actor loss: -2.58431, Critic loss: 0.44240
# [Episode 103]  Actor loss: -2.36503, Critic loss: 0.49301
# [Episode 104]  Actor loss: -9.87199, Critic loss: 0.78051
# [Episode 105]  Actor loss: -0.38585, Critic loss: 0.69938
# [Episode 106]  Actor loss: -0.76527, Critic loss: 0.40489
# [Episode 107]  Actor loss: -3.26229, Critic loss: 0.55204
# [Episode 108]  Actor loss: -1.22563, Critic loss: 0.44670
# [Episode 109]  Actor loss: 0.31075, Critic loss: 1.01193
# [Episode 110]  Actor loss: -2.51324, Critic loss: 0.58508
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 111]  Actor loss: -5.46534, Critic loss: 0.68998
# [Episode 112]  Actor loss: -8.20380, Critic loss: 0.46643
# [Episode 113]  Actor loss: -3.36209, Critic loss: 0.42882
# [Episode 114]  Actor loss: -4.46153, Critic loss: 0.35209
# [Episode 115]  Actor loss: -8.85309, Critic loss: 0.32573
# [Episode 116]  Actor loss: -8.08924, Critic loss: 0.54284
# [Episode 117]  Actor loss: -1.73997, Critic loss: 0.60132
# [Episode 118]  Actor loss: -8.09496, Critic loss: 0.44920
# [Episode 119]  Actor loss: -0.47010, Critic loss: 0.65329
# [Episode 120]  Actor loss: -4.54961, Critic loss: 0.69515
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 121]  Actor loss: -4.09714, Critic loss: 0.48170
# [Episode 122]  Actor loss: -8.33491, Critic loss: 0.26806
# [Episode 123]  Actor loss: -3.25319, Critic loss: 0.35418
# [Episode 124]  Actor loss: -5.40564, Critic loss: 0.46330
# [Episode 125]  Actor loss: -4.28616, Critic loss: 0.43088
# [Episode 126]  Actor loss: -0.37621, Critic loss: 0.73415
# [Episode 127]  Actor loss: -4.80594, Critic loss: 0.76998
# [Episode 128]  Actor loss: -6.34735, Critic loss: 0.38341
# [Episode 129]  Actor loss: -1.52822, Critic loss: 0.59168
# [Episode 130]  Actor loss: -5.37543, Critic loss: 0.42460
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 131]  Actor loss: -0.66560, Critic loss: 0.34038
# [Episode 132]  Actor loss: -7.31503, Critic loss: 0.99826
# [Episode 133]  Actor loss: -3.75060, Critic loss: 0.78105
# [Episode 134]  Actor loss: -2.38539, Critic loss: 0.59120
# [Episode 135]  Actor loss: -6.95240, Critic loss: 0.37544
# [Episode 136]  Actor loss: -4.71866, Critic loss: 0.31968
# [Episode 137]  Actor loss: -2.55715, Critic loss: 0.53665
# [Episode 138]  Actor loss: -4.46241, Critic loss: 0.37573
# [Episode 139]  Actor loss: -4.15056, Critic loss: 0.65382
# [Episode 140]  Actor loss: -6.65895, Critic loss: 0.29737
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 141]  Actor loss: -7.51866, Critic loss: 0.69029
# [Episode 142]  Actor loss: -0.23147, Critic loss: 0.60321
# [Episode 143]  Actor loss: -3.93034, Critic loss: 0.50885
# [Episode 144]  Actor loss: -4.57958, Critic loss: 0.54796
# [Episode 145]  Actor loss: -6.71089, Critic loss: 0.28474
# [Episode 146]  Actor loss: -8.66393, Critic loss: 0.44065
# [Episode 147]  Actor loss: -7.86488, Critic loss: 0.48759
# [Episode 148]  Actor loss: -8.01414, Critic loss: 0.48152
# [Episode 149]  Actor loss: -1.90889, Critic loss: 0.48663
# [Episode 150]  Actor loss: -6.04473, Critic loss: 0.65429
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 151]  Actor loss: -6.76028, Critic loss: 0.48947
# [Episode 152]  Actor loss: -6.52537, Critic loss: 0.32257
# [Episode 153]  Actor loss: -1.13196, Critic loss: 0.32764
# [Episode 154]  Actor loss: -5.39315, Critic loss: 0.32271
# [Episode 155]  Actor loss: -4.03673, Critic loss: 0.42222
# [Episode 156]  Actor loss: -2.38773, Critic loss: 0.37533
# [Episode 157]  Actor loss: -4.00815, Critic loss: 0.47693
# [Episode 158]  Actor loss: -0.32473, Critic loss: 0.62112
# [Episode 159]  Actor loss: -4.55530, Critic loss: 0.43730
# [Episode 160]  Actor loss: -2.77630, Critic loss: 0.54935
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 161]  Actor loss: -3.53646, Critic loss: 0.59096
# [Episode 162]  Actor loss: -8.99479, Critic loss: 0.72175
# [Episode 163]  Actor loss: -8.83461, Critic loss: 1.06795
# [Episode 164]  Actor loss: -2.19041, Critic loss: 0.48767
# [Episode 165]  Actor loss: -1.04932, Critic loss: 0.50071
# [Episode 166]  Actor loss: -3.53804, Critic loss: 0.36683
# [Episode 167]  Actor loss: -5.04695, Critic loss: 0.50096
# [Episode 168]  Actor loss: -0.98939, Critic loss: 0.31275
# [Episode 169]  Actor loss: -4.87391, Critic loss: 0.38336
# [Episode 170]  Actor loss: -6.21374, Critic loss: 0.44818
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 171]  Actor loss: -9.56670, Critic loss: 0.82820
# [Episode 172]  Actor loss: -6.39113, Critic loss: 0.39606
# [Episode 173]  Actor loss: -6.71756, Critic loss: 0.43563
# [Episode 174]  Actor loss: -3.67606, Critic loss: 0.56475
# [Episode 175]  Actor loss: -2.90760, Critic loss: 0.53264
# [Episode 176]  Actor loss: -8.22354, Critic loss: 0.83781
# [Episode 177]  Actor loss: -5.60813, Critic loss: 0.55935
# [Episode 178]  Actor loss: -3.83010, Critic loss: 0.47008
# [Episode 179]  Actor loss: -7.41740, Critic loss: 0.39903
# [Episode 180]  Actor loss: -5.82898, Critic loss: 0.51105
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 181]  Actor loss: -4.36102, Critic loss: 0.56935
# [Episode 182]  Actor loss: -0.39985, Critic loss: 0.37387
# [Episode 183]  Actor loss: -3.45313, Critic loss: 0.39294
# [Episode 184]  Actor loss: -4.69704, Critic loss: 0.27699
# [Episode 185]  Actor loss: -5.09181, Critic loss: 0.37867
# [Episode 186]  Actor loss: -4.63923, Critic loss: 0.38131
# [Episode 187]  Actor loss: -7.97318, Critic loss: 0.55565
# [Episode 188]  Actor loss: -4.79591, Critic loss: 0.55859
# [Episode 189]  Actor loss: -6.82905, Critic loss: 0.31802
# [Episode 190]  Actor loss: -6.69736, Critic loss: 0.25073
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 191]  Actor loss: -2.68539, Critic loss: 0.35513
# [Episode 192]  Actor loss: -0.55745, Critic loss: 0.48018
# [Episode 193]  Actor loss: -2.82765, Critic loss: 0.46140
# [Episode 194]  Actor loss: -6.20671, Critic loss: 0.32717
# [Episode 195]  Actor loss: -3.11725, Critic loss: 0.42179
# [Episode 196]  Actor loss: -2.66431, Critic loss: 0.30116
# [Episode 197]  Actor loss: -3.75699, Critic loss: 0.23207
# [Episode 198]  Actor loss: -3.58371, Critic loss: 0.67430
# [Episode 199]  Actor loss: -2.15666, Critic loss: 0.42048
# [Episode 200]  Actor loss: -4.95061, Critic loss: 0.37944
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 201]  Actor loss: -7.13790, Critic loss: 0.36708
# [Episode 202]  Actor loss: -4.10186, Critic loss: 0.35381
# [Episode 203]  Actor loss: -3.97593, Critic loss: 0.37384
# [Episode 204]  Actor loss: -3.82297, Critic loss: 0.28088
# [Episode 205]  Actor loss: -5.18206, Critic loss: 0.40124
# [Episode 206]  Actor loss: -4.61455, Critic loss: 0.36241
# [Episode 207]  Actor loss: -3.64513, Critic loss: 0.44692
# [Episode 208]  Actor loss: -7.04420, Critic loss: 0.33764
# [Episode 209]  Actor loss: -5.10132, Critic loss: 0.84044
# [Episode 210]  Actor loss: -2.78632, Critic loss: 0.54627
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 211]  Actor loss: 0.30023, Critic loss: 0.63878
# [Episode 212]  Actor loss: -4.84952, Critic loss: 0.35862
# [Episode 213]  Actor loss: -8.28366, Critic loss: 0.40943
# [Episode 218]  Actor loss: -5.03650, Critic loss: 0.32659
# [Episode 219]  Actor loss: -4.71360, Critic loss: 0.41117
# [Episode 220]  Actor loss: -3.41069, Critic loss: 0.43054
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 221]  Actor loss: -5.33161, Critic loss: 0.90600
# [Episode 222]  Actor loss: -1.61713, Critic loss: 0.60133
# [Episode 223]  Actor loss: -3.15712, Critic loss: 0.57362
# [Episode 224]  Actor loss: -4.51153, Critic loss: 0.19674
# [Episode 225]  Actor loss: -2.80158, Critic loss: 0.50993
# [Episode 226]  Actor loss: -6.26119, Critic loss: 0.26980
# [Episode 227]  Actor loss: -1.98690, Critic loss: 0.34337
# [Episode 228]  Actor loss: -3.40113, Critic loss: 0.35960
# [Episode 229]  Actor loss: -3.45532, Critic loss: 0.30153
# [Episode 230]  Actor loss: -5.37094, Critic loss: 0.26108
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 231]  Actor loss: -5.67117, Critic loss: 0.57189
# [Episode 232]  Actor loss: -8.03726, Critic loss: 0.36958
# [Episode 233]  Actor loss: -1.64325, Critic loss: 0.56685
# [Episode 234]  Actor loss: -3.72556, Critic loss: 0.36226
# [Episode 235]  Actor loss: -11.16651, Critic loss: 0.70945
# [Episode 236]  Actor loss: -4.30525, Critic loss: 0.31423
# [Episode 237]  Actor loss: -2.49260, Critic loss: 0.40578
# [Episode 238]  Actor loss: -4.08371, Critic loss: 0.43047
# [Episode 239]  Actor loss: -3.58728, Critic loss: 0.43188
# [Episode 240]  Actor loss: -7.44964, Critic loss: 0.50798
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 241]  Actor loss: -3.59682, Critic loss: 0.54652
# [Episode 242]  Actor loss: -4.77064, Critic loss: 0.38557
# [Episode 243]  Actor loss: -5.37554, Critic loss: 0.59489
# [Episode 244]  Actor loss: 0.53071, Critic loss: 0.42731
# [Episode 245]  Actor loss: -0.40111, Critic loss: 0.44129
# [Episode 246]  Actor loss: -0.44353, Critic loss: 0.34879
# [Episode 247]  Actor loss: -3.93954, Critic loss: 0.20955
# [Episode 248]  Actor loss: -2.47674, Critic loss: 0.44758
# [Episode 249]  Actor loss: -5.52419, Critic loss: 0.29177
# [Episode 250]  Actor loss: -11.71198, Critic loss: 1.08494
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 251]  Actor loss: -2.99488, Critic loss: 0.96371
# [Episode 252]  Actor loss: -5.32776, Critic loss: 0.68816
# [Episode 253]  Actor loss: -4.42442, Critic loss: 0.34026
# [Episode 254]  Actor loss: -4.20245, Critic loss: 0.36315
# [Episode 255]  Actor loss: -2.95730, Critic loss: 0.36959
# [Episode 256]  Actor loss: -5.64106, Critic loss: 0.27851
# [Episode 257]  Actor loss: -1.25486, Critic loss: 0.42364
# [Episode 258]  Actor loss: -4.86969, Critic loss: 0.29316
# [Episode 259]  Actor loss: -3.63860, Critic loss: 0.29547
# [Episode 260]  Actor loss: -6.43555, Critic loss: 0.29208
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 261]  Actor loss: -9.33556, Critic loss: 0.93704
# [Episode 262]  Actor loss: -3.75937, Critic loss: 0.55954
# [Episode 263]  Actor loss: -3.89310, Critic loss: 0.40205
# [Episode 264]  Actor loss: -3.72305, Critic loss: 0.36228
# [Episode 265]  Actor loss: -3.51003, Critic loss: 0.58694
# [Episode 266]  Actor loss: -1.61440, Critic loss: 0.47775
# [Episode 267]  Actor loss: -5.89135, Critic loss: 0.28144
# [Episode 268]  Actor loss: -6.58207, Critic loss: 0.36897
# [Episode 269]  Actor loss: -5.84196, Critic loss: 0.52275
# [Episode 270]  Actor loss: -4.58455, Critic loss: 0.38644
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 271]  Actor loss: -2.11137, Critic loss: 0.52130
# [Episode 272]  Actor loss: -0.15601, Critic loss: 0.35001
# [Episode 273]  Actor loss: -3.60760, Critic loss: 0.22059
# [Episode 274]  Actor loss: -8.30093, Critic loss: 0.28115
# [Episode 275]  Actor loss: 0.42677, Critic loss: 0.24671
# [Episode 276]  Actor loss: -4.17335, Critic loss: 0.24274
# [Episode 277]  Actor loss: -6.78587, Critic loss: 0.23830
# [Episode 278]  Actor loss: -2.70999, Critic loss: 0.24367
# [Episode 279]  Actor loss: -2.40897, Critic loss: 0.23993
# [Episode 280]  Actor loss: -5.90777, Critic loss: 0.31911
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 281]  Actor loss: -5.08791, Critic loss: 0.42576
# [Episode 282]  Actor loss: -3.67551, Critic loss: 0.32664
# [Episode 283]  Actor loss: -8.47413, Critic loss: 0.44941
# [Episode 284]  Actor loss: -7.16793, Critic loss: 0.33060
# [Episode 285]  Actor loss: -3.50398, Critic loss: 0.30737
# [Episode 286]  Actor loss: -8.15644, Critic loss: 0.23034
# [Episode 287]  Actor loss: -5.84332, Critic loss: 0.42169
# [Episode 288]  Actor loss: -5.74125, Critic loss: 0.44352
# [Episode 289]  Actor loss: -2.97808, Critic loss: 0.50761
# [Episode 290]  Actor loss: -1.80490, Critic loss: 0.58561
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 291]  Actor loss: -2.03226, Critic loss: 0.31859
# [Episode 292]  Actor loss: -1.93647, Critic loss: 0.31944
# [Episode 293]  Actor loss: -8.30365, Critic loss: 0.41907
# [Episode 294]  Actor loss: -6.77887, Critic loss: 0.45043
# [Episode 295]  Actor loss: -9.83815, Critic loss: 0.78345
# [Episode 296]  Actor loss: -5.72466, Critic loss: 0.32542
# [Episode 297]  Actor loss: -3.09529, Critic loss: 0.29090
# [Episode 298]  Actor loss: -4.49891, Critic loss: 0.35253
# [Episode 299]  Actor loss: -0.69071, Critic loss: 0.31012
# [Episode 300]  Actor loss: -3.05353, Critic loss: 0.27759
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 301]  Actor loss: -5.74641, Critic loss: 0.42612
# [Episode 302]  Actor loss: -4.81026, Critic loss: 0.31628
# [Episode 303]  Actor loss: -5.64175, Critic loss: 0.53356
# [Episode 304]  Actor loss: -6.59566, Critic loss: 0.35859
# [Episode 305]  Actor loss: -5.28032, Critic loss: 0.58769
# [Episode 306]  Actor loss: -4.21380, Critic loss: 0.34697
# [Episode 307]  Actor loss: -5.41471, Critic loss: 0.32501
# [Episode 308]  Actor loss: -4.88776, Critic loss: 0.42027
# [Episode 309]  Actor loss: -4.60915, Critic loss: 0.45195
# [Episode 310]  Actor loss: -3.32530, Critic loss: 0.37245
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 311]  Actor loss: -4.75616, Critic loss: 0.66446
# [Episode 312]  Actor loss: -6.49239, Critic loss: 1.16480
# [Episode 313]  Actor loss: -4.37338, Critic loss: 0.46467
# [Episode 314]  Actor loss: -4.22689, Critic loss: 0.34692
# [Episode 315]  Actor loss: -3.06917, Critic loss: 0.53572
# [Episode 316]  Actor loss: -6.26073, Critic loss: 0.27102
# [Episode 317]  Actor loss: -5.59213, Critic loss: 0.41510
# [Episode 318]  Actor loss: -7.62596, Critic loss: 0.31186
# [Episode 319]  Actor loss: -6.69340, Critic loss: 0.35715
# [Episode 320]  Actor loss: -5.09115, Critic loss: 0.37545
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 321]  Actor loss: -2.15372, Critic loss: 0.32202
# [Episode 322]  Actor loss: -3.33499, Critic loss: 0.34909
# [Episode 323]  Actor loss: -7.27487, Critic loss: 0.41405
# [Episode 324]  Actor loss: -3.64160, Critic loss: 0.47502
# [Episode 325]  Actor loss: -3.80857, Critic loss: 0.38346
# [Episode 326]  Actor loss: -5.56248, Critic loss: 0.49418
# [Episode 327]  Actor loss: -5.37809, Critic loss: 0.50540
# [Episode 328]  Actor loss: -5.49953, Critic loss: 0.28001
# [Episode 329]  Actor loss: -5.14436, Critic loss: 0.18658
# [Episode 330]  Actor loss: -5.20557, Critic loss: 0.24005
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 331]  Actor loss: -1.00153, Critic loss: 0.48083
# [Episode 332]  Actor loss: -4.72880, Critic loss: 0.28928
# [Episode 333]  Actor loss: -1.29468, Critic loss: 0.33687
# [Episode 334]  Actor loss: -3.68921, Critic loss: 0.40962
# [Episode 335]  Actor loss: -3.03469, Critic loss: 0.43265
# [Episode 336]  Actor loss: -7.40310, Critic loss: 0.27951
# [Episode 337]  Actor loss: -4.86210, Critic loss: 0.27113
# [Episode 338]  Actor loss: -3.20603, Critic loss: 0.23000
# [Episode 339]  Actor loss: -2.54242, Critic loss: 0.34937
# [Episode 340]  Actor loss: -8.43744, Critic loss: 0.40170
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 341]  Actor loss: -5.35932, Critic loss: 0.33648
# [Episode 342]  Actor loss: -2.85204, Critic loss: 0.38888
# [Episode 343]  Actor loss: -6.68056, Critic loss: 0.24741
# [Episode 344]  Actor loss: -3.37093, Critic loss: 0.21749
# [Episode 345]  Actor loss: -1.71872, Critic loss: 0.18774
# [Episode 346]  Actor loss: -7.47974, Critic loss: 0.38918
# [Episode 347]  Actor loss: -4.29413, Critic loss: 0.31950
# [Episode 348]  Actor loss: -3.05736, Critic loss: 0.40790
# [Episode 349]  Actor loss: -4.38744, Critic loss: 0.24153
# [Episode 350]  Actor loss: -3.08790, Critic loss: 0.33604
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 351]  Actor loss: -4.25544, Critic loss: 0.24443
# [Episode 352]  Actor loss: -6.54894, Critic loss: 0.26032
# [Episode 353]  Actor loss: -3.72613, Critic loss: 0.44696
# [Episode 354]  Actor loss: -3.13196, Critic loss: 0.32864
# [Episode 355]  Actor loss: -4.85185, Critic loss: 0.25542
# [Episode 356]  Actor loss: -5.18927, Critic loss: 0.35528
# [Episode 357]  Actor loss: -4.52503, Critic loss: 0.42482
# [Episode 358]  Actor loss: -6.87111, Critic loss: 0.31425
# [Episode 359]  Actor loss: -3.66883, Critic loss: 0.38182
# [Episode 360]  Actor loss: -8.43786, Critic loss: 0.42859
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 361]  Actor loss: -5.68671, Critic loss: 0.29805
# [Episode 362]  Actor loss: -6.32142, Critic loss: 0.20432
# [Episode 363]  Actor loss: -4.24282, Critic loss: 0.21589
# [Episode 364]  Actor loss: -2.44118, Critic loss: 0.39731
# [Episode 365]  Actor loss: -5.31768, Critic loss: 0.37423
# [Episode 366]  Actor loss: -2.32135, Critic loss: 0.33633
# [Episode 367]  Actor loss: -0.92990, Critic loss: 0.28687
# [Episode 368]  Actor loss: -4.73900, Critic loss: 0.37038
# [Episode 369]  Actor loss: -5.88197, Critic loss: 0.20273
# [Episode 370]  Actor loss: -3.58285, Critic loss: 0.43854
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 371]  Actor loss: -6.57606, Critic loss: 0.37216
# [Episode 372]  Actor loss: -0.29649, Critic loss: 0.53615
# [Episode 373]  Actor loss: -5.84875, Critic loss: 0.32765
# [Episode 374]  Actor loss: -4.88522, Critic loss: 0.38561
# [Episode 375]  Actor loss: -6.43020, Critic loss: 0.37981
# [Episode 376]  Actor loss: -7.80289, Critic loss: 1.03317
# [Episode 377]  Actor loss: -3.59656, Critic loss: 0.45881
# [Episode 378]  Actor loss: -5.64872, Critic loss: 0.41206
# [Episode 379]  Actor loss: -4.59691, Critic loss: 0.29844
# [Episode 380]  Actor loss: -3.75350, Critic loss: 0.29195
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 381]  Actor loss: -6.22711, Critic loss: 0.29506
# [Episode 382]  Actor loss: -7.38602, Critic loss: 0.19722
# [Episode 383]  Actor loss: -1.11485, Critic loss: 0.37481
# [Episode 384]  Actor loss: 0.54690, Critic loss: 0.46109
# [Episode 385]  Actor loss: -10.09480, Critic loss: 1.21366
# [Episode 386]  Actor loss: -4.44149, Critic loss: 0.49257
# [Episode 387]  Actor loss: -5.67316, Critic loss: 0.38588
# [Episode 388]  Actor loss: -4.58050, Critic loss: 0.36872
# [Episode 389]  Actor loss: -3.29377, Critic loss: 0.43532
# [Episode 390]  Actor loss: -7.83878, Critic loss: 0.44205
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 391]  Actor loss: -2.17741, Critic loss: 0.54426
# [Episode 392]  Actor loss: -3.79386, Critic loss: 0.23522
# [Episode 393]  Actor loss: -6.43956, Critic loss: 0.31545
# [Episode 394]  Actor loss: -1.52863, Critic loss: 0.22815
# [Episode 395]  Actor loss: -4.72690, Critic loss: 0.21576
# [Episode 396]  Actor loss: -4.85089, Critic loss: 0.41198
# [Episode 397]  Actor loss: -6.28653, Critic loss: 0.22978
# [Episode 398]  Actor loss: -5.31620, Critic loss: 0.23630
# [Episode 399]  Actor loss: -5.03932, Critic loss: 0.21362
# [Episode 400]  Actor loss: -5.92400, Critic loss: 0.35017
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 401]  Actor loss: -2.53007, Critic loss: 0.25376
# [Episode 402]  Actor loss: -6.54730, Critic loss: 0.21181
# [Episode 403]  Actor loss: -5.31623, Critic loss: 0.16660
# [Episode 404]  Actor loss: -4.77334, Critic loss: 0.18702
# [Episode 405]  Actor loss: -7.21244, Critic loss: 0.39745
# [Episode 406]  Actor loss: -9.04088, Critic loss: 0.19915
# [Episode 407]  Actor loss: -4.78911, Critic loss: 0.31046
# [Episode 408]  Actor loss: -1.49580, Critic loss: 0.51587
# [Episode 409]  Actor loss: -3.47396, Critic loss: 0.31718
# [Episode 410]  Actor loss: -6.07305, Critic loss: 0.31427
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 411]  Actor loss: -9.88045, Critic loss: 0.64445
# [Episode 412]  Actor loss: 0.67148, Critic loss: 0.40686
# [Episode 413]  Actor loss: -3.24747, Critic loss: 0.25223
# [Episode 414]  Actor loss: -4.78748, Critic loss: 0.24183
# [Episode 415]  Actor loss: 0.80522, Critic loss: 0.25586
# [Episode 416]  Actor loss: -4.47085, Critic loss: 0.33098
# [Episode 417]  Actor loss: -3.39377, Critic loss: 0.27142
# [Episode 418]  Actor loss: -7.46104, Critic loss: 0.30022
# [Episode 419]  Actor loss: -4.80022, Critic loss: 0.21681
# [Episode 420]  Actor loss: 0.17552, Critic loss: 0.26224
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 421]  Actor loss: -4.68635, Critic loss: 0.18423
# [Episode 422]  Actor loss: -4.79882, Critic loss: 0.28472
# [Episode 423]  Actor loss: -7.64181, Critic loss: 0.64317
# [Episode 424]  Actor loss: -4.12903, Critic loss: 0.30481
# [Episode 425]  Actor loss: -6.45557, Critic loss: 0.20811
# [Episode 426]  Actor loss: -4.35578, Critic loss: 0.27599
# [Episode 427]  Actor loss: -3.91581, Critic loss: 0.36316
# [Episode 428]  Actor loss: -6.67211, Critic loss: 0.23037
# [Episode 429]  Actor loss: -5.71730, Critic loss: 0.44311
# [Episode 430]  Actor loss: -8.11407, Critic loss: 1.33530
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 431]  Actor loss: 1.57479, Critic loss: 0.53617
# [Episode 432]  Actor loss: -6.72527, Critic loss: 0.76816
# [Episode 433]  Actor loss: -3.16056, Critic loss: 0.45183
# [Episode 434]  Actor loss: -6.22036, Critic loss: 0.28280
# [Episode 435]  Actor loss: -6.95507, Critic loss: 0.93026
# [Episode 436]  Actor loss: -6.03659, Critic loss: 0.41921
# [Episode 437]  Actor loss: -3.45631, Critic loss: 0.24773
# [Episode 438]  Actor loss: -4.22040, Critic loss: 0.44307
# [Episode 439]  Actor loss: -4.91596, Critic loss: 0.28756
# [Episode 440]  Actor loss: -5.95572, Critic loss: 0.17668
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 441]  Actor loss: -4.43311, Critic loss: 0.36082
# [Episode 442]  Actor loss: -3.86437, Critic loss: 0.20500
# [Episode 443]  Actor loss: -5.06114, Critic loss: 0.40216
# [Episode 444]  Actor loss: -5.86388, Critic loss: 0.25461
# [Episode 445]  Actor loss: -4.09651, Critic loss: 0.37677
# [Episode 446]  Actor loss: -0.49784, Critic loss: 0.48658
# [Episode 447]  Actor loss: -4.70144, Critic loss: 0.58627
# [Episode 448]  Actor loss: -3.89885, Critic loss: 0.67826
# [Episode 449]  Actor loss: -3.66920, Critic loss: 0.31917
# [Episode 450]  Actor loss: -4.98039, Critic loss: 0.85018
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 451]  Actor loss: -7.77229, Critic loss: 0.90265
# [Episode 452]  Actor loss: -5.03440, Critic loss: 0.49944
# [Episode 453]  Actor loss: -1.22293, Critic loss: 0.44973
# [Episode 454]  Actor loss: -8.55674, Critic loss: 0.45495
# [Episode 455]  Actor loss: -5.15553, Critic loss: 0.61837
# [Episode 456]  Actor loss: -5.70815, Critic loss: 0.49665
# [Episode 457]  Actor loss: -8.83076, Critic loss: 0.59458
# [Episode 458]  Actor loss: -5.12049, Critic loss: 0.35296
# [Episode 459]  Actor loss: -3.70279, Critic loss: 0.27036
# [Episode 460]  Actor loss: -4.29518, Critic loss: 0.24758
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 461]  Actor loss: -13.96548, Critic loss: 0.97071
# [Episode 462]  Actor loss: -1.32761, Critic loss: 0.50915
# [Episode 463]  Actor loss: -2.64974, Critic loss: 0.51054
# [Episode 464]  Actor loss: -1.70828, Critic loss: 0.50346
# [Episode 465]  Actor loss: -7.71375, Critic loss: 0.78361
# [Episode 466]  Actor loss: -3.41842, Critic loss: 0.26423
# [Episode 467]  Actor loss: -5.00711, Critic loss: 0.44567
# [Episode 468]  Actor loss: -0.99679, Critic loss: 0.40290
# [Episode 469]  Actor loss: -6.07337, Critic loss: 0.51961
# [Episode 470]  Actor loss: -9.80352, Critic loss: 0.49953
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 471]  Actor loss: -3.62007, Critic loss: 0.44895
# [Episode 472]  Actor loss: -4.30034, Critic loss: 0.68857
# [Episode 473]  Actor loss: -1.99775, Critic loss: 0.44192
# [Episode 474]  Actor loss: -4.67638, Critic loss: 0.55959
# [Episode 475]  Actor loss: -3.75957, Critic loss: 0.48269
# [Episode 476]  Actor loss: -3.97326, Critic loss: 0.34494
# [Episode 477]  Actor loss: -6.73178, Critic loss: 0.23596
# [Episode 478]  Actor loss: -5.53910, Critic loss: 0.61150
# [Episode 479]  Actor loss: -5.62163, Critic loss: 0.42270
# [Episode 480]  Actor loss: -6.20422, Critic loss: 0.98698
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 481]  Actor loss: -4.72786, Critic loss: 0.67179
# [Episode 482]  Actor loss: -3.95930, Critic loss: 0.79242
# [Episode 483]  Actor loss: 3.85258, Critic loss: 0.74651
# [Episode 484]  Actor loss: -4.23579, Critic loss: 0.77530
# [Episode 485]  Actor loss: -5.36618, Critic loss: 0.23881
# [Episode 486]  Actor loss: -5.49403, Critic loss: 0.35987
# [Episode 487]  Actor loss: -7.47058, Critic loss: 0.51100
# [Episode 488]  Actor loss: -9.06958, Critic loss: 1.25165
# [Episode 489]  Actor loss: -3.43296, Critic loss: 0.52856
# [Episode 490]  Actor loss: -0.30961, Critic loss: 0.46359
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 491]  Actor loss: -0.94520, Critic loss: 0.36641
# [Episode 492]  Actor loss: -10.12237, Critic loss: 0.55081
# [Episode 493]  Actor loss: -2.88258, Critic loss: 0.28112
# [Episode 494]  Actor loss: -4.12305, Critic loss: 0.23084
# [Episode 495]  Actor loss: -4.46054, Critic loss: 0.18521
# [Episode 496]  Actor loss: -4.45098, Critic loss: 0.69164
# [Episode 497]  Actor loss: -5.26976, Critic loss: 0.51948
# [Episode 498]  Actor loss: -2.72119, Critic loss: 0.42937
# [Episode 499]  Actor loss: -1.68641, Critic loss: 0.55331
# [Episode 500]  Actor loss: -6.12097, Critic loss: 0.47553
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 501]  Actor loss: -9.03507, Critic loss: 0.45115
# [Episode 502]  Actor loss: -3.05552, Critic loss: 0.33285
# [Episode 503]  Actor loss: -4.20146, Critic loss: 0.31139
# [Episode 504]  Actor loss: -11.79398, Critic loss: 1.28183
# [Episode 505]  Actor loss: -4.66421, Critic loss: 0.86589
# [Episode 506]  Actor loss: -2.74513, Critic loss: 0.61452
# [Episode 507]  Actor loss: -3.03866, Critic loss: 0.40504
# [Episode 508]  Actor loss: -4.76893, Critic loss: 1.06802
# [Episode 509]  Actor loss: -3.68850, Critic loss: 0.52734
# [Episode 510]  Actor loss: -7.35297, Critic loss: 0.90758
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 511]  Actor loss: -5.43547, Critic loss: 0.81337
# [Episode 512]  Actor loss: -4.70651, Critic loss: 0.84774
# [Episode 513]  Actor loss: -6.77293, Critic loss: 1.09323
# [Episode 514]  Actor loss: -4.66367, Critic loss: 0.71214
# [Episode 515]  Actor loss: -4.78364, Critic loss: 0.90565
# [Episode 516]  Actor loss: -7.19310, Critic loss: 0.90692
# [Episode 517]  Actor loss: -0.52626, Critic loss: 0.65119
# [Episode 518]  Actor loss: 0.29155, Critic loss: 0.40635
# [Episode 519]  Actor loss: -12.23097, Critic loss: 0.95120
# [Episode 520]  Actor loss: -3.72050, Critic loss: 0.59701
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 521]  Actor loss: -1.44165, Critic loss: 0.45832
# [Episode 522]  Actor loss: 1.47660, Critic loss: 0.48562
# [Episode 523]  Actor loss: -4.79182, Critic loss: 0.60519
# [Episode 524]  Actor loss: -11.67150, Critic loss: 2.04144
# [Episode 525]  Actor loss: -5.47325, Critic loss: 0.46327
# [Episode 526]  Actor loss: -4.18737, Critic loss: 0.84911
# [Episode 527]  Actor loss: -5.58928, Critic loss: 1.29680
# [Episode 528]  Actor loss: -7.23574, Critic loss: 0.72801
# [Episode 529]  Actor loss: -4.93102, Critic loss: 0.61762
# [Episode 530]  Actor loss: -2.23102, Critic loss: 0.60203
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 531]  Actor loss: -3.33660, Critic loss: 0.33844
# [Episode 532]  Actor loss: 0.63153, Critic loss: 0.56177
# [Episode 533]  Actor loss: -5.15680, Critic loss: 0.39099
# [Episode 534]  Actor loss: -8.38617, Critic loss: 0.88456
# [Episode 535]  Actor loss: -8.79365, Critic loss: 0.74829
# [Episode 536]  Actor loss: -2.84472, Critic loss: 0.51073
# [Episode 537]  Actor loss: -1.31388, Critic loss: 0.64033
# [Episode 538]  Actor loss: -4.97313, Critic loss: 1.30455
# [Episode 539]  Actor loss: -1.63328, Critic loss: 0.24666
# [Episode 540]  Actor loss: -2.70133, Critic loss: 0.70803
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 541]  Actor loss: -5.14195, Critic loss: 0.51532
# [Episode 542]  Actor loss: -3.50252, Critic loss: 0.27108
# [Episode 543]  Actor loss: -8.77731, Critic loss: 0.91523
# [Episode 544]  Actor loss: -14.66011, Critic loss: 1.80429
# [Episode 545]  Actor loss: -2.09387, Critic loss: 0.83453
# [Episode 546]  Actor loss: -5.11445, Critic loss: 0.83561
# [Episode 547]  Actor loss: -0.37809, Critic loss: 1.06092
# [Episode 548]  Actor loss: -4.42931, Critic loss: 0.65180
# [Episode 549]  Actor loss: -4.49918, Critic loss: 0.70345
# [Episode 550]  Actor loss: -2.74199, Critic loss: 0.30417
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 551]  Actor loss: -1.65486, Critic loss: 0.28751
# [Episode 552]  Actor loss: -1.89287, Critic loss: 0.55039
# [Episode 553]  Actor loss: -5.32192, Critic loss: 0.70810
# [Episode 554]  Actor loss: -13.11135, Critic loss: 0.73132
# [Episode 555]  Actor loss: -6.34436, Critic loss: 0.70780
# [Episode 556]  Actor loss: -3.62047, Critic loss: 0.51266
# [Episode 557]  Actor loss: -3.83514, Critic loss: 0.54269
# [Episode 558]  Actor loss: -4.54516, Critic loss: 0.82171
# [Episode 559]  Actor loss: -5.70892, Critic loss: 0.23129
# [Episode 560]  Actor loss: -0.35733, Critic loss: 0.43258
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 561]  Actor loss: -10.01342, Critic loss: 0.98181
# [Episode 562]  Actor loss: 0.03531, Critic loss: 0.52702
# [Episode 563]  Actor loss: -14.21613, Critic loss: 2.30140
# [Episode 564]  Actor loss: -5.50292, Critic loss: 1.34818
# [Episode 565]  Actor loss: -11.71866, Critic loss: 1.33582
# [Episode 566]  Actor loss: -1.31978, Critic loss: 1.13207
# [Episode 567]  Actor loss: -9.37048, Critic loss: 2.29949
# [Episode 568]  Actor loss: -3.12606, Critic loss: 0.76641
# [Episode 569]  Actor loss: -14.66308, Critic loss: 1.56414
# [Episode 570]  Actor loss: 0.05561, Critic loss: 0.60965
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 571]  Actor loss: -13.64929, Critic loss: 1.86816
# [Episode 572]  Actor loss: -10.20077, Critic loss: 3.40863
# [Episode 573]  Actor loss: 4.25623, Critic loss: 1.13779
# [Episode 574]  Actor loss: 3.11064, Critic loss: 0.87256
# [Episode 575]  Actor loss: 3.35067, Critic loss: 0.75817
# [Episode 576]  Actor loss: 3.90989, Critic loss: 0.55672
# [Episode 577]  Actor loss: -1.77169, Critic loss: 0.42228
# [Episode 578]  Actor loss: -3.31913, Critic loss: 0.59391
# [Episode 579]  Actor loss: -0.54646, Critic loss: 0.70341
# [Episode 580]  Actor loss: -13.29440, Critic loss: 0.78010
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 581]  Actor loss: -8.81642, Critic loss: 0.59541
# [Episode 582]  Actor loss: -2.67159, Critic loss: 0.77251
# [Episode 583]  Actor loss: -9.39505, Critic loss: 0.98713
# [Episode 584]  Actor loss: -4.47520, Critic loss: 0.95589
# [Episode 585]  Actor loss: -9.58154, Critic loss: 2.01017
# [Episode 586]  Actor loss: -12.76918, Critic loss: 1.81159
# [Episode 587]  Actor loss: -3.41140, Critic loss: 1.31548
# [Episode 588]  Actor loss: -0.81448, Critic loss: 0.81707
# [Episode 589]  Actor loss: -11.19971, Critic loss: 1.39847
# [Episode 590]  Actor loss: -4.97573, Critic loss: 1.73106
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 591]  Actor loss: 0.24299, Critic loss: 0.82634
# [Episode 592]  Actor loss: -7.21207, Critic loss: 0.86863
# [Episode 593]  Actor loss: -5.66536, Critic loss: 0.51574
# [Episode 594]  Actor loss: -7.37747, Critic loss: 0.89407
# [Episode 595]  Actor loss: -10.09430, Critic loss: 1.01893
# [Episode 596]  Actor loss: -3.86728, Critic loss: 0.77537
# [Episode 597]  Actor loss: -3.97437, Critic loss: 0.76907
# [Episode 598]  Actor loss: -4.67070, Critic loss: 0.66933
# [Episode 599]  Actor loss: -4.82509, Critic loss: 0.54409
# [Episode 600]  Actor loss: -3.09105, Critic loss: 0.76340
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 601]  Actor loss: -3.92382, Critic loss: 0.27277
# [Episode 602]  Actor loss: -7.87467, Critic loss: 0.99288
# [Episode 603]  Actor loss: -4.99867, Critic loss: 0.34150
# [Episode 604]  Actor loss: -5.53779, Critic loss: 0.47856
# [Episode 605]  Actor loss: -5.69015, Critic loss: 0.32924
# [Episode 606]  Actor loss: -10.95285, Critic loss: 1.12010
# [Episode 607]  Actor loss: -4.80881, Critic loss: 1.13810
# [Episode 608]  Actor loss: -12.64302, Critic loss: 0.88157
# [Episode 609]  Actor loss: -2.75803, Critic loss: 0.82935
# [Episode 610]  Actor loss: -10.33145, Critic loss: 0.88628
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 611]  Actor loss: -7.22717, Critic loss: 1.84385
# [Episode 612]  Actor loss: -6.35452, Critic loss: 1.12937
# [Episode 613]  Actor loss: -2.10288, Critic loss: 0.37535
# [Episode 614]  Actor loss: -6.58379, Critic loss: 0.66910
# [Episode 615]  Actor loss: 1.13666, Critic loss: 0.63365
# [Episode 616]  Actor loss: -10.15345, Critic loss: 1.64966
# [Episode 617]  Actor loss: -3.17938, Critic loss: 0.52810
# [Episode 618]  Actor loss: -3.45287, Critic loss: 1.15541
# [Episode 619]  Actor loss: -16.69715, Critic loss: 1.78988
# [Episode 620]  Actor loss: -2.56478, Critic loss: 1.66470
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 621]  Actor loss: -5.29121, Critic loss: 0.81405
# [Episode 622]  Actor loss: -5.10994, Critic loss: 0.92355
# [Episode 623]  Actor loss: -11.91351, Critic loss: 1.82914
# [Episode 624]  Actor loss: -11.18537, Critic loss: 1.78515
# [Episode 625]  Actor loss: 1.07014, Critic loss: 0.38555
# [Episode 626]  Actor loss: -0.26388, Critic loss: 1.08107
# [Episode 627]  Actor loss: -2.41449, Critic loss: 1.44699
# [Episode 628]  Actor loss: -7.09434, Critic loss: 1.95446
# [Episode 629]  Actor loss: -8.78782, Critic loss: 1.22203
# [Episode 630]  Actor loss: -2.45064, Critic loss: 0.66264
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 631]  Actor loss: -17.21801, Critic loss: 2.87720
# [Episode 632]  Actor loss: -4.39752, Critic loss: 1.28259
# [Episode 633]  Actor loss: -7.78577, Critic loss: 1.39010
# [Episode 634]  Actor loss: 1.71667, Critic loss: 0.72544
# [Episode 635]  Actor loss: -8.91526, Critic loss: 0.96065
# [Episode 636]  Actor loss: -7.75108, Critic loss: 0.81001
# [Episode 637]  Actor loss: -10.62265, Critic loss: 2.01388
# [Episode 638]  Actor loss: -3.07979, Critic loss: 0.93665
# [Episode 639]  Actor loss: -11.33952, Critic loss: 2.91004
# [Episode 640]  Actor loss: -5.54898, Critic loss: 1.51543
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 641]  Actor loss: -2.13544, Critic loss: 1.34081
# [Episode 642]  Actor loss: -1.42633, Critic loss: 2.46634
# [Episode 643]  Actor loss: -5.61374, Critic loss: 1.80976
# [Episode 644]  Actor loss: -5.10557, Critic loss: 0.92060
# [Episode 645]  Actor loss: -12.03622, Critic loss: 1.76400
# [Episode 646]  Actor loss: -4.11315, Critic loss: 2.04169
# [Episode 647]  Actor loss: -2.48798, Critic loss: 1.03100
# [Episode 648]  Actor loss: -8.98042, Critic loss: 2.20706
# [Episode 649]  Actor loss: -4.14918, Critic loss: 1.92720
# [Episode 650]  Actor loss: -11.70143, Critic loss: 2.50697
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 651]  Actor loss: 4.91453, Critic loss: 0.91992
# [Episode 652]  Actor loss: -1.78488, Critic loss: 0.54988
# [Episode 653]  Actor loss: -7.88577, Critic loss: 1.05036
# [Episode 654]  Actor loss: -0.98876, Critic loss: 1.74792
# [Episode 655]  Actor loss: 0.37906, Critic loss: 0.83677
# [Episode 656]  Actor loss: -2.61293, Critic loss: 0.54630
# [Episode 657]  Actor loss: -5.71868, Critic loss: 0.52886
# [Episode 658]  Actor loss: -5.56512, Critic loss: 0.51458
# [Episode 659]  Actor loss: -3.13517, Critic loss: 0.25019
# [Episode 660]  Actor loss: -8.36813, Critic loss: 0.84698
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 661]  Actor loss: -4.09953, Critic loss: 0.94774
# [Episode 662]  Actor loss: -11.88265, Critic loss: 1.28554
# [Episode 663]  Actor loss: -2.96308, Critic loss: 0.84432
# [Episode 664]  Actor loss: -6.81220, Critic loss: 0.80068
# [Episode 665]  Actor loss: -2.56741, Critic loss: 0.85860
# [Episode 666]  Actor loss: -1.29023, Critic loss: 0.88442
# [Episode 667]  Actor loss: -2.30709, Critic loss: 1.15851
# [Episode 668]  Actor loss: -8.98103, Critic loss: 1.18107
# [Episode 669]  Actor loss: -8.86010, Critic loss: 1.08545
# [Episode 670]  Actor loss: -4.87483, Critic loss: 1.34674
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 671]  Actor loss: -7.97703, Critic loss: 1.00077
# [Episode 672]  Actor loss: -4.08963, Critic loss: 1.30981
# [Episode 673]  Actor loss: -3.95308, Critic loss: 0.97993
# [Episode 674]  Actor loss: 0.39962, Critic loss: 0.53783
# [Episode 675]  Actor loss: 0.19875, Critic loss: 0.28568
# [Episode 676]  Actor loss: -1.07084, Critic loss: 0.39034
# [Episode 677]  Actor loss: -1.01833, Critic loss: 0.47985
# [Episode 678]  Actor loss: -2.51615, Critic loss: 0.32358
# [Episode 679]  Actor loss: -3.23974, Critic loss: 0.41829
# [Episode 680]  Actor loss: -7.11931, Critic loss: 0.84877
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 681]  Actor loss: -5.47608, Critic loss: 0.14583
# [Episode 682]  Actor loss: -5.75130, Critic loss: 0.77156
# [Episode 683]  Actor loss: -4.16840, Critic loss: 0.27054
# [Episode 684]  Actor loss: -3.65555, Critic loss: 0.30827
# [Episode 685]  Actor loss: -4.06844, Critic loss: 0.20014
# [Episode 686]  Actor loss: -5.96132, Critic loss: 0.71898
# [Episode 687]  Actor loss: -6.91924, Critic loss: 0.47475
# [Episode 688]  Actor loss: -3.84349, Critic loss: 0.16889
# [Episode 689]  Actor loss: -3.96998, Critic loss: 0.22087
# [Episode 690]  Actor loss: -3.19153, Critic loss: 0.29886
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 691]  Actor loss: -4.82115, Critic loss: 0.58304
# [Episode 692]  Actor loss: -3.18354, Critic loss: 0.42759
# [Episode 693]  Actor loss: -13.83852, Critic loss: 1.89223
# [Episode 694]  Actor loss: -5.88951, Critic loss: 0.33131
# [Episode 695]  Actor loss: -3.24826, Critic loss: 0.35718
# [Episode 696]  Actor loss: -6.56311, Critic loss: 0.56420
# [Episode 697]  Actor loss: -3.78915, Critic loss: 0.34587
# [Episode 698]  Actor loss: -2.57630, Critic loss: 0.21183
# [Episode 699]  Actor loss: -1.16281, Critic loss: 0.40684
# [Episode 700]  Actor loss: -8.96185, Critic loss: 0.78754
# Test average reward is -5.0, Current best average reward is -4.0
#
# ...
# [Episode 2279]  Actor loss: 17.30561, Critic loss: 5.33435
# [Episode 2280]  Actor loss: 19.16331, Critic loss: 3.70084
# Test average reward is -4.0, Current best average reward is 9.0
#
# [Episode 2281]  Actor loss: 13.48402, Critic loss: 3.04843
# [Episode 2282]  Actor loss: 4.11565, Critic loss: 3.14523
# [Episode 2283]  Actor loss: 1.45296, Critic loss: 1.44791
# [Episode 2284]  Actor loss: 0.42260, Critic loss: 1.98428
# [Episode 2285]  Actor loss: 0.32304, Critic loss: 1.35320
# [Episode 2286]  Actor loss: -4.65696, Critic loss: 2.04273
# [Episode 2287]  Actor loss: -7.17655, Critic loss: 2.63018
# [Episode 2288]  Actor loss: -19.00492, Critic loss: 3.27188
# [Episode 2289]  Actor loss: -4.38521, Critic loss: 2.26862
# [Episode 2290]  Actor loss: -9.10429, Critic loss: 3.20922
# Test average reward is -4.0, Current best average reward is 9.0
#
# [Episode 2291]  Actor loss: -4.76838, Critic loss: 3.24822
# [Episode 2292]  Actor loss: -42.03895, Critic loss: 4.66155
# [Episode 2293]  Actor loss: -15.87967, Critic loss: 6.44274
# [Episode 2294]  Actor loss: -22.19615, Critic loss: 3.12348
# [Episode 2295]  Actor loss: -4.98239, Critic loss: 4.90270
# [Episode 2296]  Actor loss: -13.83438, Critic loss: 5.98478
# [Episode 2297]  Actor loss: -22.94533, Critic loss: 6.89613
# [Episode 2298]  Actor loss: -26.05623, Critic loss: 4.92178
# [Episode 2299]  Actor loss: -15.83970, Critic loss: 9.54543
# [Episode 2300]  Actor loss: 2.65077, Critic loss: 8.00971
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2301]  Actor loss: -11.01033, Critic loss: 6.93112
# [Episode 2302]  Actor loss: -10.76495, Critic loss: 5.43408
# [Episode 2303]  Actor loss: -16.79386, Critic loss: 5.57606
# [Episode 2304]  Actor loss: -12.49282, Critic loss: 8.60402
# [Episode 2305]  Actor loss: -15.68333, Critic loss: 4.22275
# [Episode 2306]  Actor loss: 0.85688, Critic loss: 4.96880
# [Episode 2307]  Actor loss: -6.43617, Critic loss: 6.69560
# [Episode 2308]  Actor loss: -17.23570, Critic loss: 7.39837
# [Episode 2309]  Actor loss: -23.39953, Critic loss: 6.29647
# [Episode 2310]  Actor loss: -28.74099, Critic loss: 7.05735
# Test average reward is -1.0, Current best average reward is 9.0
#
# [Episode 2311]  Actor loss: -38.92048, Critic loss: 4.46160
# [Episode 2312]  Actor loss: -36.24171, Critic loss: 7.69366
# [Episode 2313]  Actor loss: 0.99124, Critic loss: 7.16822
# [Episode 2314]  Actor loss: -26.70071, Critic loss: 4.57689
# [Episode 2315]  Actor loss: 13.07307, Critic loss: 8.61842
# [Episode 2316]  Actor loss: -30.02136, Critic loss: 4.03195
# [Episode 2317]  Actor loss: 4.67684, Critic loss: 10.08933
# [Episode 2318]  Actor loss: -10.93135, Critic loss: 11.27810
# [Episode 2319]  Actor loss: 3.22247, Critic loss: 7.38520
# [Episode 2320]  Actor loss: -21.32965, Critic loss: 8.43338
# Test average reward is 0.0, Current best average reward is 9.0
#
# [Episode 2321]  Actor loss: 1.68806, Critic loss: 7.87654
# [Episode 2322]  Actor loss: 8.03151, Critic loss: 8.85710
# [Episode 2323]  Actor loss: -11.74154, Critic loss: 9.47713
# [Episode 2324]  Actor loss: -7.25821, Critic loss: 8.99439
# [Episode 2325]  Actor loss: 18.67958, Critic loss: 9.23588
# [Episode 2326]  Actor loss: 9.69986, Critic loss: 8.00007
# [Episode 2327]  Actor loss: 16.69883, Critic loss: 8.56487
# [Episode 2328]  Actor loss: 4.38133, Critic loss: 4.08710
# [Episode 2329]  Actor loss: -19.00406, Critic loss: 3.25454
# [Episode 2330]  Actor loss: -19.00498, Critic loss: 6.46005
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2331]  Actor loss: -0.92973, Critic loss: 4.39826
# [Episode 2332]  Actor loss: 10.95959, Critic loss: 3.27623
# [Episode 2333]  Actor loss: -14.95459, Critic loss: 5.31849
# [Episode 2334]  Actor loss: -17.85927, Critic loss: 3.16134
# [Episode 2335]  Actor loss: -7.14217, Critic loss: 3.47632
# [Episode 2336]  Actor loss: -23.06025, Critic loss: 8.44335
# [Episode 2337]  Actor loss: -12.20601, Critic loss: 4.84654
# [Episode 2338]  Actor loss: -17.30964, Critic loss: 6.09633
# [Episode 2339]  Actor loss: -23.15044, Critic loss: 5.04168
# [Episode 2340]  Actor loss: -25.58455, Critic loss: 6.53550
# Test average reward is 0.0, Current best average reward is 9.0
#
# [Episode 2341]  Actor loss: -13.05803, Critic loss: 9.21803
# [Episode 2342]  Actor loss: -23.71450, Critic loss: 4.28533
# [Episode 2343]  Actor loss: -14.43946, Critic loss: 5.21080
# [Episode 2344]  Actor loss: -11.15920, Critic loss: 9.10705
# [Episode 2345]  Actor loss: 5.79726, Critic loss: 8.84759
# [Episode 2346]  Actor loss: -26.67036, Critic loss: 5.28205
# [Episode 2347]  Actor loss: -19.21608, Critic loss: 5.35099
# [Episode 2348]  Actor loss: 12.84320, Critic loss: 17.64808
# [Episode 2349]  Actor loss: 25.91837, Critic loss: 7.09420
# [Episode 2350]  Actor loss: 10.53454, Critic loss: 5.75401
# Test average reward is -2.0, Current best average reward is 9.0
#
# [Episode 2351]  Actor loss: 0.81101, Critic loss: 3.22703
# [Episode 2352]  Actor loss: 1.30315, Critic loss: 4.67678
# [Episode 2353]  Actor loss: -2.45479, Critic loss: 3.50399
# [Episode 2354]  Actor loss: -0.83731, Critic loss: 3.39394
# [Episode 2355]  Actor loss: -8.55934, Critic loss: 3.25228
# [Episode 2356]  Actor loss: -11.88800, Critic loss: 5.25255
# [Episode 2357]  Actor loss: 1.44878, Critic loss: 7.94215
# [Episode 2358]  Actor loss: -33.41448, Critic loss: 6.71680
# [Episode 2359]  Actor loss: -9.97365, Critic loss: 5.50988
# [Episode 2360]  Actor loss: -16.30067, Critic loss: 9.08903
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2361]  Actor loss: -2.56453, Critic loss: 3.80113
# [Episode 2362]  Actor loss: -13.49070, Critic loss: 3.94233
# [Episode 2363]  Actor loss: -12.85053, Critic loss: 7.04006
# [Episode 2364]  Actor loss: -17.21529, Critic loss: 8.55174
# [Episode 2365]  Actor loss: -14.10287, Critic loss: 4.32090
# [Episode 2366]  Actor loss: -7.12841, Critic loss: 6.02662
# [Episode 2367]  Actor loss: 12.02574, Critic loss: 5.63796
# [Episode 2368]  Actor loss: 2.68573, Critic loss: 6.64876
# [Episode 2369]  Actor loss: -0.50160, Critic loss: 5.67669
# [Episode 2370]  Actor loss: -20.34939, Critic loss: 3.47575
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2371]  Actor loss: 5.54899, Critic loss: 4.71556
# [Episode 2372]  Actor loss: -4.53596, Critic loss: 6.18945
# [Episode 2373]  Actor loss: -6.48597, Critic loss: 9.89300
# [Episode 2374]  Actor loss: -4.48119, Critic loss: 5.94426
# [Episode 2375]  Actor loss: -10.38524, Critic loss: 3.63772
# [Episode 2376]  Actor loss: 10.24563, Critic loss: 4.94138
# [Episode 2377]  Actor loss: -1.90251, Critic loss: 6.22137
# [Episode 2378]  Actor loss: -1.13937, Critic loss: 7.17141
# [Episode 2379]  Actor loss: -15.90781, Critic loss: 4.02901
# [Episode 2380]  Actor loss: -4.33313, Critic loss: 4.25686
# Test average reward is -4.0, Current best average reward is 9.0
#
# [Episode 2381]  Actor loss: -14.71137, Critic loss: 6.76980
# [Episode 2382]  Actor loss: -6.28450, Critic loss: 6.95138
# [Episode 2383]  Actor loss: -9.83367, Critic loss: 5.93263
# [Episode 2384]  Actor loss: 3.48374, Critic loss: 3.60661
# [Episode 2385]  Actor loss: -0.11068, Critic loss: 7.91340
# [Episode 2386]  Actor loss: 6.69114, Critic loss: 3.20312
# [Episode 2387]  Actor loss: -16.79124, Critic loss: 3.00808
# [Episode 2388]  Actor loss: -11.69599, Critic loss: 4.22043
# [Episode 2389]  Actor loss: -24.24097, Critic loss: 5.82706
# [Episode 2390]  Actor loss: -27.75809, Critic loss: 3.45362
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2391]  Actor loss: -33.70803, Critic loss: 5.64491
# [Episode 2392]  Actor loss: -4.72625, Critic loss: 3.13144
# [Episode 2393]  Actor loss: -13.34758, Critic loss: 4.69348
# [Episode 2394]  Actor loss: 0.32719, Critic loss: 6.68562
# [Episode 2395]  Actor loss: -12.32991, Critic loss: 5.18526
# [Episode 2396]  Actor loss: 6.58828, Critic loss: 7.00628
# [Episode 2397]  Actor loss: -31.33678, Critic loss: 3.59963
# [Episode 2398]  Actor loss: -25.26037, Critic loss: 3.25347
# [Episode 2399]  Actor loss: 6.09454, Critic loss: 7.44235
# [Episode 2400]  Actor loss: 7.56556, Critic loss: 9.13396
# Test average reward is 1.0, Current best average reward is 9.0
#
# [Episode 2401]  Actor loss: -7.06027, Critic loss: 4.28496
# [Episode 2402]  Actor loss: -15.53683, Critic loss: 5.67424
# [Episode 2403]  Actor loss: -29.29077, Critic loss: 7.43612
# [Episode 2404]  Actor loss: -4.48486, Critic loss: 8.15868
# [Episode 2405]  Actor loss: -6.44473, Critic loss: 10.59130
# [Episode 2406]  Actor loss: 5.18005, Critic loss: 6.02836
# [Episode 2407]  Actor loss: 9.51922, Critic loss: 4.97126
# [Episode 2408]  Actor loss: 12.00821, Critic loss: 6.77599
# [Episode 2409]  Actor loss: -8.19151, Critic loss: 6.85472
# [Episode 2410]  Actor loss: -27.35844, Critic loss: 4.34689
# Test average reward is 3.0, Current best average reward is 9.0
#
# [Episode 2411]  Actor loss: -35.03916, Critic loss: 7.02744
# [Episode 2412]  Actor loss: -13.26490, Critic loss: 7.56131
# [Episode 2416]  Actor loss: -30.10583, Critic loss: 6.74717
# [Episode 2417]  Actor loss: -5.46826, Critic loss: 13.51181
# [Episode 2418]  Actor loss: -24.40521, Critic loss: 6.88117
# [Episode 2419]  Actor loss: -23.32849, Critic loss: 8.38464
# [Episode 2420]  Actor loss: 0.65060, Critic loss: 4.92809
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2421]  Actor loss: -22.44672, Critic loss: 9.23115
# [Episode 2422]  Actor loss: -5.83995, Critic loss: 7.30113
# [Episode 2423]  Actor loss: -6.46538, Critic loss: 12.12705
# [Episode 2424]  Actor loss: 4.17463, Critic loss: 7.90082
# [Episode 2425]  Actor loss: -8.60842, Critic loss: 5.27282
# [Episode 2426]  Actor loss: 1.12535, Critic loss: 8.89839
# [Episode 2427]  Actor loss: -2.53095, Critic loss: 12.34778
# [Episode 2428]  Actor loss: -0.55593, Critic loss: 8.81493
# [Episode 2429]  Actor loss: 1.42124, Critic loss: 11.35290
# [Episode 2430]  Actor loss: -33.81623, Critic loss: 7.97926
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2431]  Actor loss: -22.48435, Critic loss: 8.42851
# [Episode 2432]  Actor loss: 6.16917, Critic loss: 12.50714
# [Episode 2433]  Actor loss: 1.02022, Critic loss: 11.85165
# [Episode 2434]  Actor loss: -28.06319, Critic loss: 7.98542
# [Episode 2435]  Actor loss: 2.78856, Critic loss: 8.21332
# [Episode 2436]  Actor loss: -44.30170, Critic loss: 7.14251
# [Episode 2437]  Actor loss: -2.13563, Critic loss: 17.20409
# [Episode 2438]  Actor loss: -13.71535, Critic loss: 13.03868
# [Episode 2439]  Actor loss: -2.01588, Critic loss: 11.64924
# [Episode 2440]  Actor loss: 29.91051, Critic loss: 10.54093
# Test average reward is -3.0, Current best average reward is 9.0
#
# [Episode 2441]  Actor loss: 13.38715, Critic loss: 11.25705
# [Episode 2442]  Actor loss: 13.69566, Critic loss: 9.01102
# [Episode 2443]  Actor loss: -25.56111, Critic loss: 9.98133
# [Episode 2444]  Actor loss: 2.10951, Critic loss: 10.33755
# [Episode 2445]  Actor loss: -37.08001, Critic loss: 7.50710
# [Episode 2446]  Actor loss: 0.66650, Critic loss: 14.34476
# [Episode 2447]  Actor loss: -15.42987, Critic loss: 12.37449
# [Episode 2448]  Actor loss: 8.94421, Critic loss: 8.85584
# [Episode 2449]  Actor loss: 17.04551, Critic loss: 6.46154
# [Episode 2450]  Actor loss: -6.07091, Critic loss: 5.60904
# Test average reward is 1.0, Current best average reward is 9.0
#
# [Episode 2451]  Actor loss: 9.40085, Critic loss: 8.51445
# [Episode 2452]  Actor loss: -1.28380, Critic loss: 6.29646
# [Episode 2453]  Actor loss: -0.95329, Critic loss: 2.53536
# [Episode 2454]  Actor loss: -8.93244, Critic loss: 11.00484
# [Episode 2455]  Actor loss: -16.57397, Critic loss: 3.84201
# [Episode 2456]  Actor loss: -7.09796, Critic loss: 4.39337
# [Episode 2457]  Actor loss: 1.22455, Critic loss: 6.80059
# [Episode 2458]  Actor loss: -25.11110, Critic loss: 7.87313
# [Episode 2459]  Actor loss: -2.64164, Critic loss: 10.49403
# [Episode 2460]  Actor loss: -2.91096, Critic loss: 8.36026
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2461]  Actor loss: -1.40206, Critic loss: 6.59443
# [Episode 2462]  Actor loss: 9.47858, Critic loss: 9.64704
# [Episode 2463]  Actor loss: -17.24631, Critic loss: 7.08820
# [Episode 2464]  Actor loss: -20.22990, Critic loss: 8.32788
# [Episode 2465]  Actor loss: 12.37174, Critic loss: 7.65026
# [Episode 2466]  Actor loss: -19.32873, Critic loss: 4.96064
# [Episode 2467]  Actor loss: 1.79731, Critic loss: 3.99955
# [Episode 2468]  Actor loss: -22.47148, Critic loss: 6.36486
# [Episode 2469]  Actor loss: -12.07326, Critic loss: 7.50551
# [Episode 2470]  Actor loss: -17.08863, Critic loss: 4.71006
# Test average reward is 7.0, Current best average reward is 9.0
#
# [Episode 2471]  Actor loss: 5.27066, Critic loss: 7.15513
# [Episode 2472]  Actor loss: -22.92075, Critic loss: 5.50430
# [Episode 2473]  Actor loss: -37.80805, Critic loss: 11.09580
# [Episode 2474]  Actor loss: -3.06566, Critic loss: 3.47867
# [Episode 2475]  Actor loss: -12.73024, Critic loss: 5.97004
# [Episode 2476]  Actor loss: -19.57160, Critic loss: 3.89521
# [Episode 2477]  Actor loss: -44.92276, Critic loss: 4.38592
# [Episode 2478]  Actor loss: -34.26898, Critic loss: 6.73747
# [Episode 2479]  Actor loss: -2.11846, Critic loss: 13.91873
# [Episode 2480]  Actor loss: -1.70120, Critic loss: 7.80959
# Test average reward is -1.0, Current best average reward is 9.0
#
# [Episode 2481]  Actor loss: -28.86983, Critic loss: 4.27684
# [Episode 2482]  Actor loss: -12.31776, Critic loss: 14.47377
# [Episode 2483]  Actor loss: 13.17887, Critic loss: 21.37626
# [Episode 2484]  Actor loss: -0.28737, Critic loss: 15.75103
# [Episode 2485]  Actor loss: -15.59152, Critic loss: 8.18034
# [Episode 2486]  Actor loss: -26.99447, Critic loss: 6.71128
# [Episode 2487]  Actor loss: -25.68789, Critic loss: 7.62472
# [Episode 2488]  Actor loss: -3.68890, Critic loss: 9.59081
# [Episode 2489]  Actor loss: -24.88813, Critic loss: 6.75143
# [Episode 2490]  Actor loss: -17.88238, Critic loss: 16.36227
# Test average reward is -2.0, Current best average reward is 9.0
#
# [Episode 2491]  Actor loss: -7.81413, Critic loss: 9.15533
# [Episode 2492]  Actor loss: -22.00264, Critic loss: 4.65507
# [Episode 2493]  Actor loss: -15.90854, Critic loss: 19.24310
# [Episode 2494]  Actor loss: 33.29216, Critic loss: 21.88164
# [Episode 2495]  Actor loss: 33.77928, Critic loss: 16.42772
# [Episode 2496]  Actor loss: 7.64421, Critic loss: 11.52834
# [Episode 2497]  Actor loss: 8.66710, Critic loss: 9.25172
# [Episode 2498]  Actor loss: 0.09923, Critic loss: 9.22656
# [Episode 2499]  Actor loss: 6.77766, Critic loss: 8.63963
# [Episode 2500]  Actor loss: -6.28772, Critic loss: 12.94204
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 2501]  Actor loss: 2.43621, Critic loss: 11.67433
# [Episode 2502]  Actor loss: -1.63848, Critic loss: 6.52908
# [Episode 2503]  Actor loss: -17.32151, Critic loss: 7.31699
# [Episode 2504]  Actor loss: -0.21229, Critic loss: 8.62409
# [Episode 2505]  Actor loss: -29.81614, Critic loss: 3.89609
# [Episode 2506]  Actor loss: -5.51808, Critic loss: 9.68475
# [Episode 2507]  Actor loss: -24.87859, Critic loss: 6.54952
# [Episode 2508]  Actor loss: -18.73426, Critic loss: 5.66406
# [Episode 2509]  Actor loss: -27.45732, Critic loss: 6.82136
# [Episode 2510]  Actor loss: -26.11569, Critic loss: 6.28144
# Test average reward is -1.0, Current best average reward is 9.0
#
# [Episode 2511]  Actor loss: 6.51260, Critic loss: 12.80658
# [Episode 2512]  Actor loss: -8.03762, Critic loss: 9.45371
# [Episode 2513]  Actor loss: -5.85634, Critic loss: 17.09874
# [Episode 2514]  Actor loss: -1.73673, Critic loss: 6.63347
# [Episode 2515]  Actor loss: -22.06721, Critic loss: 12.36614
# [Episode 2516]  Actor loss: -19.33584, Critic loss: 6.43829
# [Episode 2517]  Actor loss: -13.76431, Critic loss: 9.12181
# [Episode 2518]  Actor loss: -18.18118, Critic loss: 6.06125
# [Episode 2519]  Actor loss: 24.96294, Critic loss: 12.68627
# [Episode 2520]  Actor loss: 13.46906, Critic loss: 15.08584
# Test average reward is 13.0, Current best average reward is 9.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_2520_13.0/assets
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_2520_13.0/assets

# %% [markdown]
# ## 2. Result

# %%
clip = make_anim(display_frames, fps=60, true_image=True).rotate(-90)
clip.write_videofile("movie_f/{}_demo-{}.webm".format('Lab15', 2520), fps=60)
display(clip.ipython_display(fps=60, autoplay=1, loop=1, maxduration=120))
# Out:
# Moviepy - Building video movie_f/Lab15_demo-2520.webm.
# Moviepy - Writing video movie_f/Lab15_demo-2520.webm
# Moviepy - Done !
# Moviepy - video ready movie_f/Lab15_demo-2520.webm
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video autoplay='1' loop='1'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# ## 3. Report

# %% [markdown]
# 在這份 PPO X GAE 的 notebook 中，model 主要有以下兩個部分。
#
# - `ActorCriticNetwork` 是使用 deep neural network 來取代之前 state 的部分，他的 input 會是由 `frames_to_state` function 將一串 frame 取最後 4 張 concate 起來成一張 image (將channel concate 起來)，而這個 image 首先會經由 CNN 作為 feature extractor，再將 feature 分別由 actor network 和 critic network 產生 action 的 softmax output 和 state value，這兩個 network 都是只用一層 Dense 所組成的。
#
# - `Agent` 則是實作了 PPO 的演算法，包括 PPO 的 update 和從環境做 sample，其中使用了剛剛的 `ActorCriticNetwork`，並用 `Adam` 做為 optimizer，在 update 時會去對 PPO ratio 做 clip。
#
# 再來 GAE 的部分是實作在 `compute_gae` function 中，會估算出 total reward。
#
# 最後是 training 的過程，在每個 epoch 會先跑過固定的 step，並對 PPO 做 update。另外在每十個 epoch 就會去 test 的環境做測試，計算出平均 reward，並記錄下最好的平均 reward，當這個 reward 大於我們設定的 10 時，就會提前結束 training 過程。
#
# 在我的測試中，actor loss 和 critic loss 大致上都會維持在同一個區間震盪，每過一段時間後又會到不同區間繼續震盪，除了一開始之外，沒有很明顯的下降趨勢。而測試的平均 reward 是在第 1830 epoch 時才從 0 衝到 9，最後在第 2520 epoch 超過 10，到達 13，這時的 flappy bird 可以通過最多 5 根管子。
